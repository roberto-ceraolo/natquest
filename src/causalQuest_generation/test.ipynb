# %%
# load /Users/rob/Documenti_offline_4_real/github_repos/causalquest-acl2025-data/data/causalquest_acl25.csv

import pandas as pd

df = pd.read_csv("/Users/rob/Documenti_offline_4_real/github_repos/causalquest-acl2025-data/data/causalquest_acl25.csv")

df.head()
# Out:
#    query_id      causal_type            source  \
# 0      7717              NaN  naturalQuestions
# 1      9720              NaN  naturalQuestions
# 2      8767              NaN  naturalQuestions
# 3      8452              NaN  naturalQuestions
# 4      7688  About Variables  naturalQuestions
#
#                                                query  \
# 0  ben may main library - mobile public library m...
# 1              who is the oldest child on family guy
# 2          where will the 2020 olympic games be held
# 3            write a note on history of tea in india
# 4              rush we are the priests of the temple
#
#                                      shortened_query  \
# 0  ben may main library - mobile public library m...
# 1              who is the oldest child on family guy
# 2          where will the 2020 olympic games be held
# 3            write a note on history of tea in india
# 4              rush we are the priests of the temple
#
# ...

# %%
# print the schema 
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13500 entries, 0 to 13499
# Data columns (total 13 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   query_id         13500 non-null  int64
#  1   causal_type      5701 non-null   object
#  2   source           13500 non-null  object
#  3   query            13500 non-null  object
#  4   shortened_query  13500 non-null  object
#  5   is_causal_raw    13500 non-null  object
#  6   is_causal        13500 non-null  bool
#  7   domain_class     5694 non-null   object
#  8   action_class     5694 non-null   object
#  9   is_subjective    5694 non-null   object
#  10  bloom_taxonomy   13497 non-null  object
#  11  user_needs       13500 non-null  object
#  12  uniqueness       13496 non-null  object
# dtypes: bool(1), int64(1), object(11)
# memory usage: 1.2+ MB
